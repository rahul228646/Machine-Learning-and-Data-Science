# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style="darkgrid")
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv()

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
data.shape
# Out:
# (1459, 80)

# %%
df = pd.DataFrame(data["LotFrontage"], data["LotFrontage"], data["SalePrice"])

# %%
df.fillna()
# Out:
# SalePrice 208500 181500 223500 140000 250000 143000 307000 200000 129900  \
# count          0      0      0      0      0      0      0      0      0
# unique         0      0      0      0      0      0      0      0      0
# top          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# freq         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# SalePrice 118000  ... 136000 287090 145000 84500  185000 175000 210000 266500  \
# count          0  ...      0      0      0      0      0      0      0      0
# unique         0  ...      0      0      0      0      0      0      0      0
# top          NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# freq         NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# SalePrice 142125 147500
# count          0      0
# unique         0      0
# top          NaN    NaN
# freq         NaN    NaN
#
# [4 rows x 1460 columns]

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
# x = data['Height']
# y = data['Weight']

# %%
y = scaled_data.T[0]
x = scaled_data.T[1]
w, w_o = 110, 110
Lr = 0.01
slope = []
intercept = []
error = []
j = []
i = 0
while i < 1000:
    j.append(i)
    slope.append(w);
    intercept.append(w_o)
    e = np.sum((y - (w*x + w_o))**2)
    error.append(e)
    dw = -2*np.sum(x*(y - (w*x+w_o)))
    dw_o = -2*np.sum((y - (w*x+w_o)))
    w = w - (dw*Lr)
    w_o = w_o - (dw_o*Lr)
    i = i+1
w, w_o
# Out:
# /opt/miniconda3/envs/env/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /var/folders/w8/1mb65r517w14x3ry7s6m9xnc0000gn/T/ipykernel_6928/3965672507.py:14: RuntimeWarning: overflow encountered in square
#   e = np.sum((y - (w*x + w_o))**2)
# /var/folders/w8/1mb65r517w14x3ry7s6m9xnc0000gn/T/ipykernel_6928/3965672507.py:16: RuntimeWarning: overflow encountered in double_scalars
#   dw = -2*np.sum(x*(y - (w*x+w_o)))
# /var/folders/w8/1mb65r517w14x3ry7s6m9xnc0000gn/T/ipykernel_6928/3965672507.py:17: RuntimeWarning: overflow encountered in double_scalars
#   dw_o = -2*np.sum((y - (w*x+w_o)))
# /var/folders/w8/1mb65r517w14x3ry7s6m9xnc0000gn/T/ipykernel_6928/3965672507.py:14: RuntimeWarning: invalid value encountered in add
#   e = np.sum((y - (w*x + w_o))**2)
# /var/folders/w8/1mb65r517w14x3ry7s6m9xnc0000gn/T/ipykernel_6928/3965672507.py:16: RuntimeWarning: invalid value encountered in add
#   dw = -2*np.sum(x*(y - (w*x+w_o)))
# /var/folders/w8/1mb65r517w14x3ry7s6m9xnc0000gn/T/ipykernel_6928/3965672507.py:17: RuntimeWarning: invalid value encountered in add
#   dw_o = -2*np.sum((y - (w*x+w_o)))
# (nan, nan)

# %%
sns.lineplot(x = np.array(j), y = np.array(error));
plt.xlabel("Iterations",fontsize=15);
plt.ylabel("Error", fontsize=15);
